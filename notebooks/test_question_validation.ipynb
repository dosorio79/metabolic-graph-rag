# %%
import pandas as pd
import sys
import os

# Add the absolute path to the rag directory
sys.path.append('../')
from backend.app.rag.pipeline import run_rag_pipeline
from backend.app.schemas.rag import RAGRequest

# %%
# Create a dataframe with metabolic questions:
manual_test_questions = {
    "Questions": [
        # Producers
        "How is pyruvate produced?",
        "What reactions produce C00022?",
        "How is oxaloacetate synthesized?",
        "Which enzymes produce glucose?",
        "How is lactate generated?",

        # Consumers
        "What consumes glucose?",
        "Which reactions use C00031?",
        "What degrades lactate?",
        "What pathways break down pyruvate?",
        "Describe enzymes that use glucose",

        # Participants
        "Which enzymes act on glucose?",
        "List participants in R00200",
        "What are the reactants in R01070?",
        "enzyme ec 1.1.1.1",
        "participants in map00010",

        # Summary
        "What is glycolysis pathway?",
        "Tell me about C00022",
        "Describe R00200",
        "Overview of hsa00010",
        "What is EC 2.7.1.1?",

        # Unknown / edge
        "about pyruvate",
        "C00022",
        "Hi there",
        "random text with no biology",
        "   ",
    ]
}
test_df = pd.DataFrame(manual_test_questions)

# %%
test_df
# Out:
#                              Questions
# 0            How is pyruvate produced?
# 1       What reactions produce C00022?
# 2     How is oxaloacetate synthesized?
# 3       Which enzymes produce glucose?
# 4            How is lactate generated?
# 5               What consumes glucose?
# 6          Which reactions use C00031?
# 7               What degrades lactate?
# 8   What pathways break down pyruvate?
# 9    Describe enzymes that use glucose
# 10       Which enzymes act on glucose?
# 11         List participants in R00200
# 12   What are the reactants in R01070?
# 13                   enzyme ec 1.1.1.1
# 14            participants in map00010
# 15         What is glycolysis pathway?
# 16                Tell me about C00022
# 17                     Describe R00200
# 18                Overview of hsa00010
# 19                 What is EC 2.7.1.1?
# 20                      about pyruvate
# 21                              C00022
# 22                            Hi there
# 23         random text with no biology
# 24

# %%
test_df.iloc[0,0]
# Out:
# 'How is pyruvate produced?'

# %%
# Create a rag request object for the first question
rag_request = RAGRequest(question=test_df.iloc[0,0])

# %%
run_rag_pipeline(rag_request)
# Out:
# RAGResponse(answer='LLM response unavailable. Reason: missing APP_LLM_API_KEY. Question: How is pyruvate produced? | Context length: 387', interpretation=RAGInterpretation(entity_type='compound', entity_id=None, entity_name='pyruvate', intent='producers', confidence=0.7999999999999999), context='Metabolic Graph Context\n\nInterpretation:\n- entity_type: compound\n- intent: producers\n- entity_id: C00022\n- entity_name: pyruvate\n\nCounts:\n- reactions: 1\n- compounds: 1\n- enzymes: 0\n\nReactions:\n- R01196 (pyruvate:ferredoxin 2-oxidoreductase (CoA-acetylating))\n\nCompounds:\n- C00022 (Pyruvate)\n\nTrace IDs:\n- reaction_ids: R01196\n- compound_ids: C00022\n- pathway_ids: none\n- enzyme_ecs: none', reactions=[RAGReactionSummary(reaction_id='R01196', name='pyruvate:ferredoxin 2-oxidoreductase (CoA-acetylating)')], compounds=[RAGCompoundSummary(compound_id='C00022', name='Pyruvate')], enzymes=[], trace=RAGTrace(reaction_ids=['R01196'], compound_ids=['C00022'], pathway_ids=[], enzyme_ecs=[]))

# %%
# Run for all questions
def rag_questions_to_df(questions: list[str]) -> pd.DataFrame:
    rows = []

    for q in questions:
        try:
            resp = run_rag_pipeline(RAGRequest(question=q))
            rows.append(
                {
                    "question": q,
                    "answer": resp.answer,
                    "intent": resp.interpretation.intent,
                    "entity_type": resp.interpretation.entity_type,
                    "entity_id": resp.interpretation.entity_id,
                    "entity_name": resp.interpretation.entity_name,
                    "confidence": resp.interpretation.confidence,
                    "resolved_entity_id": resp.trace.compound_ids[0] if resp.trace.compound_ids else None,
                    "reactions_n": len(resp.reactions),
                    "compounds_n": len(resp.compounds),
                    "enzymes_n": len(resp.enzymes),
                    "reaction_ids": ", ".join(r.reaction_id for r in resp.reactions) or None,
                    "compound_ids": ", ".join(c.compound_id for c in resp.compounds) or None,
                    "enzyme_ecs": ", ".join(resp.enzymes) or None,
                    "error": None,
                }
            )
        except Exception as e:
            rows.append(
                {
                    "question": q,
                    "answer": None,
                    "intent": None,
                    "entity_type": None,
                    "entity_id": None,
                    "entity_name": None,
                    "confidence": None,
                    "resolved_entity_id": None,
                    "reactions_n": None,
                    "compounds_n": None,
                    "enzymes_n": None,
                    "reaction_ids": None,
                    "compound_ids": None,
                    "enzyme_ecs": None,
                    "error": str(e),
                }
            )

    return pd.DataFrame(rows)

# %%
answers_df = rag_questions_to_df(test_df["Questions"])
# Out:
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: equation)", position=<SummaryInputPosition line=27, column=8, offset=596>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 8, 'offset': 596, 'line': 27}}> for query: '\n\tMATCH (r:Reaction {id: $reaction_id})\n\tCALL {\n\t\tWITH r\n\t\tMATCH (c:Compound)-[rel:CONSUMED_BY]->(r)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS substrates\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[rel:PRODUCES]->(c:Compound)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS products\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[:CATALYZED_BY]->(e:Enzyme)\n\t\tWITH e\n\t\tORDER BY e.ec\n\t\tRETURN collect(e.ec) AS enzymes\n\t}\n\tRETURN r.id AS reaction_id,\n\t\t   r.name AS name,\n\t\t   r.definition AS definition,\n\t\t   r.equation AS equation,\n\t\t   r.reversible AS reversible,\n\t\t   substrates,\n\t\t   products,\n\t\t   enzymes\n\t'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: equation)", position=<SummaryInputPosition line=27, column=8, offset=596>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 8, 'offset': 596, 'line': 27}}> for query: '\n\tMATCH (r:Reaction {id: $reaction_id})\n\tCALL {\n\t\tWITH r\n\t\tMATCH (c:Compound)-[rel:CONSUMED_BY]->(r)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS substrates\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[rel:PRODUCES]->(c:Compound)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS products\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[:CATALYZED_BY]->(e:Enzyme)\n\t\tWITH e\n\t\tORDER BY e.ec\n\t\tRETURN collect(e.ec) AS enzymes\n\t}\n\tRETURN r.id AS reaction_id,\n\t\t   r.name AS name,\n\t\t   r.definition AS definition,\n\t\t   r.equation AS equation,\n\t\t   r.reversible AS reversible,\n\t\t   substrates,\n\t\t   products,\n\t\t   enzymes\n\t'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: equation)", position=<SummaryInputPosition line=27, column=8, offset=596>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 8, 'offset': 596, 'line': 27}}> for query: '\n\tMATCH (r:Reaction {id: $reaction_id})\n\tCALL {\n\t\tWITH r\n\t\tMATCH (c:Compound)-[rel:CONSUMED_BY]->(r)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS substrates\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[rel:PRODUCES]->(c:Compound)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS products\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[:CATALYZED_BY]->(e:Enzyme)\n\t\tWITH e\n\t\tORDER BY e.ec\n\t\tRETURN collect(e.ec) AS enzymes\n\t}\n\tRETURN r.id AS reaction_id,\n\t\t   r.name AS name,\n\t\t   r.definition AS definition,\n\t\t   r.equation AS equation,\n\t\t   r.reversible AS reversible,\n\t\t   substrates,\n\t\t   products,\n\t\t   enzymes\n\t'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: equation)", position=<SummaryInputPosition line=27, column=8, offset=596>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 8, 'offset': 596, 'line': 27}}> for query: '\n\tMATCH (r:Reaction {id: $reaction_id})\n\tCALL {\n\t\tWITH r\n\t\tMATCH (c:Compound)-[rel:CONSUMED_BY]->(r)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS substrates\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[rel:PRODUCES]->(c:Compound)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS products\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[:CATALYZED_BY]->(e:Enzyme)\n\t\tWITH e\n\t\tORDER BY e.ec\n\t\tRETURN collect(e.ec) AS enzymes\n\t}\n\tRETURN r.id AS reaction_id,\n\t\t   r.name AS name,\n\t\t   r.definition AS definition,\n\t\t   r.equation AS equation,\n\t\t   r.reversible AS reversible,\n\t\t   substrates,\n\t\t   products,\n\t\t   enzymes\n\t'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: equation)", position=<SummaryInputPosition line=27, column=8, offset=596>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 8, 'offset': 596, 'line': 27}}> for query: '\n\tMATCH (r:Reaction {id: $reaction_id})\n\tCALL {\n\t\tWITH r\n\t\tMATCH (c:Compound)-[rel:CONSUMED_BY]->(r)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS substrates\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[rel:PRODUCES]->(c:Compound)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS products\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[:CATALYZED_BY]->(e:Enzyme)\n\t\tWITH e\n\t\tORDER BY e.ec\n\t\tRETURN collect(e.ec) AS enzymes\n\t}\n\tRETURN r.id AS reaction_id,\n\t\t   r.name AS name,\n\t\t   r.definition AS definition,\n\t\t   r.equation AS equation,\n\t\t   r.reversible AS reversible,\n\t\t   substrates,\n\t\t   products,\n\t\t   enzymes\n\t'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: equation)", position=<SummaryInputPosition line=27, column=8, offset=596>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 8, 'offset': 596, 'line': 27}}> for query: '\n\tMATCH (r:Reaction {id: $reaction_id})\n\tCALL {\n\t\tWITH r\n\t\tMATCH (c:Compound)-[rel:CONSUMED_BY]->(r)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS substrates\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[rel:PRODUCES]->(c:Compound)\n\t\tWITH c, rel\n\t\tORDER BY c.id\n\t\tRETURN collect({compound_id: c.id, name: c.name, coef: rel.coef}) AS products\n\t}\n\tCALL {\n\t\tWITH r\n\t\tMATCH (r)-[:CATALYZED_BY]->(e:Enzyme)\n\t\tWITH e\n\t\tORDER BY e.ec\n\t\tRETURN collect(e.ec) AS enzymes\n\t}\n\tRETURN r.id AS reaction_id,\n\t\t   r.name AS name,\n\t\t   r.definition AS definition,\n\t\t   r.equation AS equation,\n\t\t   r.reversible AS reversible,\n\t\t   substrates,\n\t\t   products,\n\t\t   enzymes\n\t'

# %%
answers_df
# Out:
#                               question  \
# 0            How is pyruvate produced?
# 1       What reactions produce C00022?
# 2     How is oxaloacetate synthesized?
# 3       Which enzymes produce glucose?
# 4            How is lactate generated?
# 5               What consumes glucose?
# 6          Which reactions use C00031?
# 7               What degrades lactate?
# 8   What pathways break down pyruvate?
# 9    Describe enzymes that use glucose
# 10       Which enzymes act on glucose?
# 11         List participants in R00200
# 12   What are the reactants in R01070?
# 13                   enzyme ec 1.1.1.1
# 14            participants in map00010
# 15         What is glycolysis pathway?
# 16                Tell me about C00022
# 17                     Describe R00200
# 18                Overview of hsa00010
# 19                 What is EC 2.7.1.1?
# 20                      about pyruvate
# 21                              C00022
# 22                            Hi there
# 23         random text with no biology
# 24
#
#                                                answer        intent  \
# 0   LLM response unavailable. Reason: missing APP_...     producers
# 1   LLM response unavailable. Reason: missing APP_...     producers
# 2   LLM response unavailable. Reason: missing APP_...     producers
# 3   LLM response unavailable. Reason: missing APP_...     producers
# 4   LLM response unavailable. Reason: missing APP_...     producers
# 5   LLM response unavailable. Reason: missing APP_...     consumers
# 6   LLM response unavailable. Reason: missing APP_...       summary
# 7   LLM response unavailable. Reason: missing APP_...     consumers
# 8   LLM response unavailable. Reason: missing APP_...     consumers
# 9   LLM response unavailable. Reason: missing APP_...       summary
# 10  LLM response unavailable. Reason: missing APP_...  participants
# 11  LLM response unavailable. Reason: missing APP_...  participants
# 12  LLM response unavailable. Reason: missing APP_...  participants
# 13  LLM response unavailable. Reason: missing APP_...  participants
# 14  LLM response unavailable. Reason: missing APP_...  participants
# 15  LLM response unavailable. Reason: missing APP_...       summary
# 16  LLM response unavailable. Reason: missing APP_...       summary
# 17  LLM response unavailable. Reason: missing APP_...       summary
# 18  LLM response unavailable. Reason: missing APP_...       summary
# 19  LLM response unavailable. Reason: missing APP_...       summary
# 20  LLM response unavailable. Reason: missing APP_...       summary
# 21  LLM response unavailable. Reason: missing APP_...       summary
# 22  LLM response unavailable. Reason: missing APP_...       unknown
# 23  LLM response unavailable. Reason: missing APP_...       unknown
# 24                                                NaN           NaN
#
#    entity_type entity_id   entity_name  confidence resolved_entity_id  \
# 0     compound       NaN      pyruvate        0.80             C00022
# 1     compound    C00022           NaN        0.80             C00022
# 2     compound       NaN  oxaloacetate        0.80             C00036
# 3       enzyme       NaN           NaN        0.60                NaN
# 4     compound       NaN       lactate        0.80                NaN
# 5     compound       NaN       glucose        0.80             C00267
# 6     compound    C00031        c00031        0.99                NaN
# 7     compound       NaN       lactate        0.80                NaN
# 8     compound       NaN      pyruvate        0.65             C00022
# 9       enzyme       NaN       glucose        0.80                NaN
# 10    compound       NaN       glucose        0.65             C00267
# 11    reaction    R00200        r00200        0.99             C00002
# 12    reaction    R01070        r01070        0.99                NaN
# 13      enzyme   1.1.1.1           NaN        0.95                NaN
# 14     pathway  map00010      map00010        0.99                NaN
# 15     pathway       NaN           NaN        0.60                NaN
# 16    compound    C00022        c00022        0.99             C00022
# 17    reaction    R00200           NaN        0.95             C00002
# 18     pathway  hsa00010      hsa00010        0.99                NaN
# 19      enzyme   2.7.1.1           NaN        0.95                NaN
# 20     unknown       NaN      pyruvate        0.70                NaN
# 21    compound    C00022           NaN        0.95             C00022
# 22     unknown       NaN           NaN        0.00                NaN
# 23     unknown       NaN           NaN        0.00                NaN
# 24         NaN       NaN           NaN         NaN                NaN
#
#     reactions_n  compounds_n  enzymes_n  \
# 0           1.0          1.0        0.0
# 1           1.0          1.0        0.0
# 2           0.0          1.0        0.0
# 3           0.0          0.0        0.0
# 4           0.0          0.0        0.0
# 5           3.0          1.0        0.0
# 6           0.0          0.0        0.0
# 7           0.0          0.0        0.0
# 8           4.0          1.0        0.0
# 9           0.0          0.0        0.0
# 10          3.0          1.0        4.0
# 11          1.0          4.0        1.0
# 12          0.0          0.0        0.0
# 13          0.0          0.0        0.0
# 14          0.0          0.0        0.0
# 15          0.0          0.0        0.0
# 16          5.0          1.0        0.0
# 17          1.0          4.0        1.0
# 18         27.0          0.0        0.0
# 19          1.0          0.0        1.0
# 20          0.0          0.0        0.0
# 21          5.0          1.0        0.0
# 22          0.0          0.0        0.0
# 23          0.0          0.0        0.0
# 24          NaN          NaN        NaN
#
#                                          reaction_ids  \
# 0                                              R01196
# 1                                              R01196
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                              R01786, R02189, R09085
# 6                                                 NaN
# 7                                                 NaN
# 8                      R00014, R00200, R00209, R10866
# 9                                                 NaN
# 10                             R01786, R02189, R09085
# 11                                             R00200
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16             R01196, R00014, R00200, R00209, R10866
# 17                                             R00200
# 18  R00014, R00200, R00209, R00341, R00431, R00658...
# 19                                             R01786
# 20                                                NaN
# 21             R01196, R00014, R00200, R00209, R10866
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                       compound_ids                             enzyme_ecs  \
# 0                           C00022                                    NaN
# 1                           C00022                                    NaN
# 2                           C00036                                    NaN
# 3                              NaN                                    NaN
# 4                              NaN                                    NaN
# 5                           C00267                                    NaN
# 6                              NaN                                    NaN
# 7                              NaN                                    NaN
# 8                           C00022                                    NaN
# 9                              NaN                                    NaN
# 10                          C00267  2.7.1.1, 2.7.1.147, 2.7.1.2, 2.7.1.63
# 11  C00002, C00022, C00008, C00074                               2.7.1.40
# 12                             NaN                                    NaN
# 13                             NaN                                    NaN
# 14                             NaN                                    NaN
# 15                             NaN                                    NaN
# 16                          C00022                                    NaN
# 17  C00002, C00022, C00008, C00074                               2.7.1.40
# 18                             NaN                                    NaN
# 19                             NaN                                2.7.1.1
# 20                             NaN                                    NaN
# 21                          C00022                                    NaN
# 22                             NaN                                    NaN
# 23                             NaN                                    NaN
# 24                             NaN                                    NaN
#
#                                                 error
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  1 validation error for RAGRequest\nquestion\n ...

# %%
# Validation checks for Task 3 manual question validation
expected_cases = pd.DataFrame(
    {
        "question": manual_test_questions["Questions"],
        "expected_intent": [
            # Producers
            "producers", "producers", "producers", "producers", "producers",
            # Consumers
            "consumers", "consumers", "consumers", "consumers", "consumers",
            # Participants
            "participants", "participants", "participants", "participants", "participants",
            # Summary
            "summary", "summary", "summary", "summary", "summary",
            # Unknown / edge
            "summary", "summary", "unknown", "unknown", "unknown",
        ],
        "expected_entity_type": [
            # Producers
            "compound", "compound", "compound", "compound", "compound",
            # Consumers
            "compound", "compound", "compound", "compound", "compound",
            # Participants
            "compound", "reaction", "reaction", "enzyme", "pathway",
            # Summary
            "pathway", "compound", "reaction", "pathway", "enzyme",
            # Unknown / edge
            "unknown", "compound", "unknown", "unknown", "unknown",
        ],
        "expect_grounding": [
            # Producers
            True, True, True, True, True,
            # Consumers
            True, True, True, True, True,
            # Participants
            True, True, True, True, True,
            # Summary
            True, True, True, True, True,
            # Unknown / edge
            False, True, False, False, False,
        ],
    }
)

validation_df = answers_df.merge(expected_cases, on="question", how="left")

validation_df["is_valid_input"] = validation_df["error"].isna()
validation_df["is_intent_ok"] = validation_df["intent"] == validation_df["expected_intent"]
validation_df["is_entity_type_ok"] = validation_df["entity_type"] == validation_df["expected_entity_type"]


def _has_grounding(row: pd.Series) -> bool:
    if pd.notna(row["error"]):
        return False
    return any((row["reactions_n"] or 0, row["compounds_n"] or 0, row["enzymes_n"] or 0))


validation_df["is_grounded_ok"] = validation_df.apply(
    lambda row: (not row["expect_grounding"]) or _has_grounding(row), axis=1
)
validation_df["is_pass"] = (
    validation_df["is_intent_ok"]
    & validation_df["is_entity_type_ok"]
    & validation_df["is_grounded_ok"]
    & validation_df["is_valid_input"]
)

valid_rows = validation_df[validation_df["is_valid_input"]]
summary_df = pd.DataFrame(
    {
        "metric": [
            "intent_accuracy",
            "entity_type_accuracy",
            "grounding_pass_rate",
            "overall_pass_rate",
            "overall_pass_rate_valid_inputs",
        ],
        "value": [
            validation_df["is_intent_ok"].mean(),
            validation_df["is_entity_type_ok"].mean(),
            validation_df["is_grounded_ok"].mean(),
            validation_df["is_pass"].mean(),
            valid_rows["is_pass"].mean() if not valid_rows.empty else 0.0,
        ],
    }
)
summary_df["value"] = (summary_df["value"] * 100).round(1)

summary_df

# %%
# Show only failed validation rows for quick debugging
failed_cols = [
    "question",
    "expected_intent",
    "intent",
    "expected_entity_type",
    "entity_type",
    "expect_grounding",
    "reactions_n",
    "compounds_n",
    "enzymes_n",
    "error",
    "is_valid_input",
    "is_intent_ok",
    "is_entity_type_ok",
    "is_grounded_ok",
    "is_pass",
]

failed_df = validation_df.loc[~validation_df["is_pass"], failed_cols].copy()
failed_df
